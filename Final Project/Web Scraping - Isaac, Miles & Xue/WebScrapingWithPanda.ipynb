# %%
import pandas as pd
# https://stat.as.uky.edu/grad-students
# https://finance.yahoo.com/most-active
url = 'https://finance.yahoo.com/most-active'
dfs = pd.read_html(url)

# %%
dfs
# Out:
# [   Symbol                               Name  Price (Intraday)  Change  \
#  0     AMD       Advanced Micro Devices, Inc.             11.04    1.33
#  1       T                          AT&T Inc.             33.10   -2.10
#  2       F                 Ford Motor Company             11.43    0.32
#  3      FB                     Facebook, Inc.            174.16   14.47
#  4      GE           General Electric Company             14.38    0.33
#  5     NOK                  Nokia Corporation              5.87   -0.05
#  6    TWTR                      Twitter, Inc.             30.27    0.52
#  7     MDR      McDermott International, Inc.              7.06    0.27
#  8     BAC        Bank of America Corporation             30.07   -0.07
#  9      MU            Micron Technology, Inc.             50.14    2.54
#  10    MGM          MGM Resorts International             32.29   -3.04
#  11  CMCSA                Comcast Corporation             33.33   -0.93
# ...

# %%
# Out:
#   File "<ipython-input-8-082288494568>", line 1
#     image_scraper.scrape_images(https://stat.as.uky.edu/users/ztal223)
#                                      ^
# SyntaxError: invalid syntax
